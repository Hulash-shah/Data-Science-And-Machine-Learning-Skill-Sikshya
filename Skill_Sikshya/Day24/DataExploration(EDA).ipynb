# %%
import pandas as pd

titanic_df = pd.read_csv(
    r"C:\Users\shahh\OneDrive\Desktop\Data Science And Machine Learning\Skill_Sikshya\Day22\titanic_data.csv",
    delimiter = ",",
    header = 0
    )

titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Basic Information

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
titanic_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# The Titanic dataset contains 891 passenger records and 12 columns, including age, gender, passenger class, fare, and survival status. It contains some missing values, particularly in Age, Cabin, and Embarked. The dataset is widely used for practicing Pandas, data analysis, and machine learning.

# %% [markdown]
# Specific Information

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Stat info : mean Q1 median Q3 max min mode std corr
titanic_df[["Age", "Fare"]].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
titanic_df[["Age", "Fare"]].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
titanic_df[["Age", "Fare"]].std()
# Out:
# Age     14.526497
# Fare    49.693429
# dtype: float64

# %%
titanic_df[["Age", "Fare"]].mode()
# Out:
#     Age  Fare
# 0  24.0  8.05

# %%
titanic_df[["Age", "Fare"]].count()
# Out:
# Age     714
# Fare    891
# dtype: int64

# %%
titanic_df[["Age", "Fare"]].var()
# Out:
# Age      211.019125
# Fare    2469.436846
# dtype: float64

# %%
titanic_df[["Age", "Fare"]].min()
# Out:
# Age     0.42
# Fare    0.00
# dtype: float64

# %%
titanic_df[["Age", "Fare"]].max()
# Out:
# Age      80.0000
# Fare    512.3292
# dtype: float64

# %%
titanic_df[["Age", "Fare"]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %% [markdown]
# Titanic Dataset – Age & Fare Analysis
#
# • The dataset contains 891 passengers.
# • Age has 714 valid values and 177 missing values.
# • The average passenger age is 29.7 years.
# • The median passenger age is 28 years.
# • Passenger ages range from 0.42 to 80 years.
# • The average fare is 32.20.
# • The median fare is 14.45.
# • Fare values range from 0 to 512.33.
# • The difference between mean and median fare shows that Fare is right-skewed.
# • The maximum fare of 512.33 indicates the presence of outliers.
# • 75% of passengers paid a fare of 31 or less.
# • Age and Fare show considerable variation among passengers.
# • Missing Age values should be handled before further analysis or machine learning.

# %%
# Counts
titanic_df.value_counts("Embarked")
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
titanic_df.value_counts("Embarked", normalize = True, ascending = False, dropna = True)
# Out:
# Embarked
# S    0.724409
# C    0.188976
# Q    0.086614
# Name: proportion, dtype: float64

# %%
titanic_df.value_counts("Cabin", normalize = False, dropna = True)
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F33            3
# E101           3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
titanic_df.value_counts(["Sex", "Survived"], normalize = True)
# Out:
# Sex     Survived
# male    0           0.525253
# female  1           0.261504
# male    1           0.122334
# female  0           0.090909
# Name: proportion, dtype: float64

# %%
titanic_df[titanic_df.Sex == "female"].value_counts("Survived")
# Out:
# Survived
# 1    233
# 0     81
# Name: count, dtype: int64

# %%
# Embarked from s , Fare Distribution
titanic_df[titanic_df.Embarked == "S"]["Fare"].describe()
# Out:
# count    644.000000
# mean      27.079812
# std       35.887993
# min        0.000000
# 25%        8.050000
# 50%       13.000000
# 75%       27.900000
# max      263.000000
# Name: Fare, dtype: float64

# %%
# embarked from S , male , survied
s_male = titanic_df[(titanic_df["Embarked"] == "S") & (titanic_df["Sex"] == "male")].value_counts("Survived")
s_male
# Out:
# Survived
# 0    364
# 1     77
# Name: count, dtype: int64
