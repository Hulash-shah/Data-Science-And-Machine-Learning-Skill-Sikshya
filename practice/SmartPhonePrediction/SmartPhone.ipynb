# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\shahh\OneDrive\Desktop\Data Science And Machine Learning\practice\SmartPhonePrediction\test.csv",
                   index_col = 0)
data.head()
# Out:
#          age  daily_screen_time_hours  social_media_hours  gaming_hours  \
# id
# 691369  30.0                     9.34                 NaN          0.77
# 691370   NaN                      NaN                1.91           NaN
# 691371  26.0                     8.48                3.64           NaN
# 691372  20.0                     8.37                2.99          1.69
# 691373  25.0                     8.25                4.02          1.21
#
#         work_study_hours  sleep_hours  notifications_per_day  \
# id
# 691369              4.09         7.15                  153.0
# 691370              1.20         8.67                  239.0
# 691371              3.39         7.47                  106.0
# 691372              2.53         5.45                  178.0
# 691373              2.32         8.46                   63.0
#
#         app_opens_per_day  weekend_screen_time  gender stress_level  \
# id
# 691369               16.0                  NaN   Other       Medium
# ...

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
n_c = [
    "daily_screen_time_hours",
    "social_media_hours",
    "gaming_hours",
    "work_study_hours"
]
sample = data[n_c].sample(10000, random_state=42)

scaler = StandardScaler()
scaled_data = scaler.fit_transform(sample)

imputer = KNNImputer(n_neighbors=5)
imputed_data = imputer.fit_transform(scaled_data)

print("Done!")
# Out:
# Done!

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 296302 entries, 691369 to 987670
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   age                      279164 non-null  float64
#  1   daily_screen_time_hours  263514 non-null  float64
#  2   social_media_hours       248905 non-null  float64
#  3   gaming_hours             236882 non-null  float64
#  4   work_study_hours         268525 non-null  float64
#  5   sleep_hours              273847 non-null  float64
#  6   notifications_per_day    262081 non-null  float64
#  7   app_opens_per_day        270597 non-null  float64
#  8   weekend_screen_time      245605 non-null  float64
#  9   gender                   282090 non-null  str
#  10  stress_level             276676 non-null  str
#  11  academic_work_impact     270581 non-null  str
# dtypes: float64(9), str(3)
# memory usage: 27.1 MB

# %%
data.isna().sum()
# Out:
# age                        17138
# daily_screen_time_hours    32788
# social_media_hours         47397
# gaming_hours               59420
# work_study_hours           27777
# sleep_hours                22455
# notifications_per_day      34221
# app_opens_per_day          25705
# weekend_screen_time        50697
# gender                     14212
# stress_level               19626
# academic_work_impact       25721
# dtype: int64

# %%
data.shape
# Out:
# (296302, 12)
