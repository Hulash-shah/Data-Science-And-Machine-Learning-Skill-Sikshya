# %%
d1 = {"a": 10 , "b": 20 , "c" : 30}
d2 = {"c": 40, "d": 50 , "e" : 60}

for i in d2:
    d1[i] = d2[i]

# %%
d1
# Out:
# {'a': 10, 'b': 20, 'c': 40, 'd': 50, 'e': 60}

# %%
d1 = {"a": 10 , "b": 20 , "c" : 30}
sum = 0
for i in d1:
    sum += d1[i]

sum
# Out:
# 60

# %%
# counting the frequency of elements in the list
list = ["a","b","a","c","b","a"]

d = {}

for i in list:
    if i in d.keys():
        d[i] = d[i] + 1
    else:
        d[i] = 1
        
d
# Out:
# {'a': 3, 'b': 2, 'c': 1}
